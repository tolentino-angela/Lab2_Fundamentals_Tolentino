# %%
corrrect_password = "ADMIN" # You can change this attempts = 0
while True:
    user_input = input("Enter password: ")
    attempts += 1
    is user_input == correct_password:
        print("Unlocked")
        break
    else:
        print("Acess Denied.")
